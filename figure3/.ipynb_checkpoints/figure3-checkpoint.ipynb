# %%
import sys
sys.path.append("..")
from sense_experiment import *

# %%
# run experiment for synthetic data
fn_prefix = 'synth_data'
snr_db_vals = [5,10,15,20]
r_retro_vec = np.r_[1:9:5] # change!
r_pro_vec = [1,4] # change!
data_nm = 'bart_phantom'
n_bart_threads = 8
verbose = True
for snr_db in snr_db_vals[0:1]:
    pro_retro_sense_experiment(fn_out=fn_prefix+'_snrdb{}'.format(snr_db), data_nm='bart_phantom', snr_db=snr_db, \
                               r_retro_vec = r_retro_vec, r_pro_vec=r_pro_vec, \
                                n_bart_threads=n_bart_threads,verbose=verbose)
# Out:
# Done.
# Doing z usamp: False
# Done.
# Replace kspace
# lambda = 0.000010, NRMSE = 0.000000
# Replace kspace
# lambda = 0.000032, NRMSE = 0.000000
# Replace kspace
# lambda = 0.000100, NRMSE = 0.000000
# Replace kspace
# lambda = 0.000316, NRMSE = 0.000000
# Replace kspace
# lambda = 0.001000, NRMSE = 0.001000
# Replace kspace
# lambda = 0.003162, NRMSE = 0.003000
# Replace kspace
# lambda = 0.010000, NRMSE = 0.010000
# Replace kspace
# lambda = 0.031623, NRMSE = 0.031000
# Replace kspace
# lambda = 0.100000, NRMSE = 0.091000
# Replace kspace
# lambda = 0.316228, NRMSE = 0.240000
# Replace kspace
# lambda = 1.000000, NRMSE = 0.500000
# r_pro = 1, nrmse = 0.000000
# Doing z usamp: False
# Done.
# Replace kspace
# lambda = 0.000010, NRMSE = 0.000000
# Replace kspace
# lambda = 0.000032, NRMSE = 0.000000
# Replace kspace
# lambda = 0.000100, NRMSE = 0.000000
# Replace kspace
# lambda = 0.000316, NRMSE = 0.000000
# Replace kspace
# lambda = 0.001000, NRMSE = 0.001000
# Replace kspace
# lambda = 0.003162, NRMSE = 0.003000
# Replace kspace
# lambda = 0.010000, NRMSE = 0.010000
# Replace kspace
# lambda = 0.031623, NRMSE = 0.031000
# Replace kspace
# lambda = 0.100000, NRMSE = 0.091000
# Replace kspace
# lambda = 0.316228, NRMSE = 0.240000
# Replace kspace
# lambda = 1.000000, NRMSE = 0.500000
# r_retro = 1, nmrse = 0.000000
# Doing z usamp: False
# Done.
# Replace kspace
# lambda = 0.000010, NRMSE = 5.576000
# Replace kspace
# lambda = 0.000032, NRMSE = 5.519000
# Replace kspace
# lambda = 0.000100, NRMSE = 5.351000
# Replace kspace
# lambda = 0.000316, NRMSE = 4.886000
# Replace kspace
# lambda = 0.001000, NRMSE = 3.873000
# Replace kspace
# lambda = 0.003162, NRMSE = 2.499000
# Replace kspace
# lambda = 0.010000, NRMSE = 1.490000
# Replace kspace
# lambda = 0.031623, NRMSE = 0.963000
# Replace kspace
# lambda = 0.100000, NRMSE = 0.679000
# Replace kspace
# lambda = 0.316228, NRMSE = 0.594000
# Replace kspace
# lambda = 1.000000, NRMSE = 0.689000
# r_retro = 6, nmrse = 0.594000
# Completed subexperiment for r_pro = 1 in 14.48495602607727 sec
# Done.
# Doing z usamp: False
# Done.
# Replace kspace
# lambda = 0.000010, NRMSE = 4.302000
# Replace kspace
# lambda = 0.000032, NRMSE = 4.269000
# Replace kspace
# lambda = 0.000100, NRMSE = 4.172000
# Replace kspace
# lambda = 0.000316, NRMSE = 3.894000
# Replace kspace
# lambda = 0.001000, NRMSE = 3.251000
# Replace kspace
# lambda = 0.003162, NRMSE = 2.285000
# Replace kspace
# lambda = 0.010000, NRMSE = 1.475000
# Replace kspace
# lambda = 0.031623, NRMSE = 0.975000
# Replace kspace
# lambda = 0.100000, NRMSE = 0.669000
# Replace kspace
# lambda = 0.316228, NRMSE = 0.565000
# Replace kspace
# lambda = 1.000000, NRMSE = 0.667000
# r_pro = 4, nrmse = 0.565000
# Doing z usamp: False
# Done.
# Replace kspace
# lambda = 0.000010, NRMSE = 0.316000
# Replace kspace
# lambda = 0.000032, NRMSE = 0.316000
# Replace kspace
# lambda = 0.000100, NRMSE = 0.316000
# Replace kspace
# lambda = 0.000316, NRMSE = 0.316000
# Replace kspace
# lambda = 0.001000, NRMSE = 0.315000
# Replace kspace
# lambda = 0.003162, NRMSE = 0.312000
# Replace kspace
# lambda = 0.010000, NRMSE = 0.303000
# Replace kspace
# lambda = 0.031623, NRMSE = 0.276000
# Replace kspace
# lambda = 0.100000, NRMSE = 0.197000
# Replace kspace
# lambda = 0.316228, NRMSE = 0.000000
# Replace kspace
# lambda = 1.000000, NRMSE = 0.342000
# r_retro = 1, nmrse = 0.000000
# Doing z usamp: False
# Done.
# Replace kspace
# lambda = 0.000010, NRMSE = 5.496000
# Replace kspace
# lambda = 0.000032, NRMSE = 5.441000
# Replace kspace
# lambda = 0.000100, NRMSE = 5.277000
# Replace kspace
# lambda = 0.000316, NRMSE = 4.822000
# Replace kspace
# lambda = 0.001000, NRMSE = 3.823000
# Replace kspace
# lambda = 0.003162, NRMSE = 2.446000
# Replace kspace
# lambda = 0.010000, NRMSE = 1.409000
# Replace kspace
# lambda = 0.031623, NRMSE = 0.851000
# Replace kspace
# lambda = 0.100000, NRMSE = 0.532000
# Replace kspace
# lambda = 0.316228, NRMSE = 0.411000
# Replace kspace
# lambda = 1.000000, NRMSE = 0.539000
# r_retro = 6, nmrse = 0.411000
# Completed subexperiment for r_pro = 4 in 16.87073588371277 sec

# %%
# plot from saved data    
nrmse_mat = np.load(fn_prefix+'_snrdb{}'.format(snr_db)+'_nrmse.npy')
r_retro_vec = np.load(fn_prefix+'_snrdb{}'.format(snr_db)+'_r_retro_vec.npy')
r_pro_vec = np.load(fn_prefix+'_snrdb{}'.format(snr_db)+'_r_pro_vec.npy')

ftsz=24
plt.figure(figsize=(12,8))
plt.plot(r_retro_vec,nrmse_mat,linewidth=4)
    
plt.rc('font', size=ftsz)
plt.xticks(r_retro_vec, size=ftsz); plt.yticks(np.r_[0:0.8:0.05],size=ftsz);
plt.legend(['$R_{pro}$' +'={}'.format(r_pro) if r_pro>1 else '$R_{pro}$' +'={}'.format(r_pro) for r_pro in r_pro_vec],fontsize=ftsz);
plt.xlabel('$R_{retro}$',size=ftsz)
plt.ylabel('NRMSE',size=ftsz);plt.ylim([0, 0.7]);
plt.title('SNR = {} dB'.format(snr_db));
